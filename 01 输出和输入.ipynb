# %% [markdown]
# # 输出和输入
# ## Python版本
# 请在下列单元格中写下Python的两个版本：

# %% [markdown]
# 1)
# 2)

# %% [markdown]
# ## print()函数

# %% [markdown]
# ### 请编写程序，打印出下面的图案
# ![image.png](attachment:0f4502d8-73b5-4ca8-861e-a6ce5694b64e.png)

# %%
# 答案

# %% [markdown]
# ## input()函数

# %% [markdown]
# ## 课堂小结
# ### print()的用法
# ![image.png](attachment:b49d4824-6038-47ee-94ec-b2a867bfb27b.png)

# %% [markdown]
# ### input()的用法
# ![image.png](attachment:3a95b44a-085b-495e-bd22-7fbaa490cb4c.png)

# %% [markdown]
# ## 课堂练习

# %% [markdown]
# ## 本课重点单词（函数）
#
# * **print**：打印（输出到屏幕）
# * **input**：输入（输入信息到电脑）
